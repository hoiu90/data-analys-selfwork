# %% [markdown]
# #Qicheng Sun。 82857     Lab 7
#
# ## **1. Matplotlib charts description**
#
# To begin with, it’s a good idea to familiarize yourself with the (English) terminology for the elements that make up the chart view. The graphic below will help you identify these elements and customize the chart to suit the requirements or needs of a given task or problem.
#
# ![Charts anatomy](./images/anatomy.png)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Sample charts

# %% [markdown]
# ### 2.1 Line plot

# %% [markdown]
# > **Docs**: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %% [markdown]
# **Listing 1**

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('y axis label')
plt.show()

# %% [markdown]
# The code above is written in the format typically used in traditional Python scripts. Jupyter Notebook has a special backend and magic methods that usually have additional functionality in notebooks. The `matplotlib` package can also be used with this backend (more here: [https://ipython.readthedocs.io/en/stable/interactive/plotting.html](https://ipython.readthedocs.io/en/stable/interactive/plotting.html).
# This frees us from having to use `plt.show()`, but it also prints a string representation of the last line of code (the object) to the console. You can avoid this by assigning this statement to a variable or adding a `;` at the end of the code.

# %% [markdown]
# **Listing 2**

# %%
# activation of matplotlib inline backend
# %matplotlib inline
plt.ylabel('y axis label')
plt.plot([1, 2, 3, 4]);

# %% [markdown]
# The vector of the passed values is the Y-axis, and the X-axis was generated automatically; here, for each value in the Y-vector, it simply takes the corresponding index value from this list—that is, for the value 1, it takes the value 0, and so on.

# %% [markdown]
# **Listing 3**

# %%
# We pass two vectors of values, first for the x-axis, then for the y-axis
# Additionally, we have a string parameter here that specifies the chart style
# For a complete list, see the documentation at
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro-')

# below we set up a limit of values for each axis [xmin, xmax, ymin, ymax]
plt.axis([0, 6, 0, 20])
plt.title('Chart 1')
plt.show()

# We can also set different colors for individual elements by overlaying two charts
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'r')
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'o')
plt.title('Chart 2')

plt.axis([0, 6, 0, 20])
# Out:
# (np.float64(0.0), np.float64(6.0), np.float64(0.0), np.float64(20.0))

# %% [markdown]
# **Listing 4**

# %%
import numpy as np

# base value vector
t = np.arange(0., 5., 0.2)

# With a single call to the plot() function, we can generate multiple plots on a single canvas
# each time specifying the necessary values: values for the x-axis, values for the y-axis, plot style, ...
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^');

# %% [markdown]
# **Listing 5**

# %%
x = np.linspace(0, 2, 100)

# Plots can also be added to the canvas one by one instead of using a single call to the plot() function
# Here, the label parameter is also used to specify the label for a given plot in the legend
plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

# axis labels
plt.xlabel('x')
plt.ylabel('f(x)')

# plot title
plt.title("Simple line plot")

# enables plot legend
plt.legend();

# %% [markdown]
# **Listing 6**

# %%
x = np.arange(0, 10, 0.1)
s = np.sin(x)
plt.plot(x, s, label='sin(x)')

# axis labels
plt.xlabel('x')
plt.ylabel('sin(x)')

# plot title
plt.title("Plot of the sin(x) function)")

# plot legend
plt.legend();

# %% [markdown]
# ### 2.2. Scatter plot

# %% [markdown]
# > **Docs**: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html

# %% [markdown]
# **Listing 7**

# %%
# data in dictionary format, but it could just as easily be a Pandas DataFrame
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

# To pass the plot parameters in this way, you must include the required `data` parameter, which contains data accessible via labels
# This means that ‘a’ is equivalent to `data[‘a’]`, and so on. The `c` parameter is short for `color`, passed here as a vector
# color values for each successive value of the plot. The parameter s stands for scale—it specifies the size, in this case of the point, for
# each successive value of the plot vector. In summary, the following values will be used for the first point of the plot
print(f"a={data['a'][0]}, b={data['b'][0]}, c={data['c'][0]}, d={data['d'][0]}")
plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('a')
plt.ylabel('b');
# Out:
# a=0, b=9.323388431416678, c=48, d=103.7232281930109

# %% [markdown]
# ### 2.3 Subplots

# %% [markdown]
# Subplots allow you to place multiple plots on a single canvas, arranged in a grid. You specify the grid dimensions, i.e., the number of rows and the number of columns. This is done using the `subplot` function, which takes three arguments (`nrows, ncols, index`). These correspond to the number of grid rows, the number of columns, and the index of the plot being defined (indices start at 1 and end at `nrows*ncols`).

# %% [markdown]
# **Listing 8**

# %%
x1 = np.arange(0.0, 2.0, 0.02)
x2 = np.arange(0.0, 2.0, 0.02)

y1 = np.sin(2 * np.pi * x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(2, 1, 1)
plt.plot(x1, y1, '-')
plt.title('Two subplots')
plt.ylabel('sin(x)')

plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r-')
plt.xlabel('x')
plt.ylabel('cos(x)');

# %% [markdown]
# **Listing 9**

# %%
# another example

x1 = np.arange(0.0, 2.0, 0.02)
x2 = np.arange(0.0, 2.0, 0.02)
y1 = np.sin(2 * np.pi * x1)
y2 = np.cos(2 * np.pi * x2)

# indicates that this is a 3x2 grid (3 rows, 2 columns) and we are defining a chart with index 1
plt.subplot(3, 2, 1)
plt.plot(x1, y1, '-')
plt.title('Two subplots')
plt.ylabel('sin(x)')

# We can also omit the commas; here, the graph has an index of 4, so we omitted 2 and 3
plt.subplot(324)
plt.plot(x2, y2, 'r-')
plt.xlabel('x')
plt.ylabel('cos(x)')

plt.subplot(3, 2, 5)
plt.plot(x2, y2, 'r-')
plt.xlabel('x')
plt.ylabel('cos(x)');

# %% [markdown]
# ### 2.4 Bar plot

# %% [markdown]
# > **Docs**:
# > * vertical: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
# > * horizontal: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.barh.html

# %% [markdown]
# **Listing 10**

# %%
# very simple bar plot example

labels = ['Female', 'Male']
values = [345, 435]

plt.bar(labels, values)
# We can also change, for example, the text direction of the pole labels to save some space
plt.xticks(rotation=45)
plt.ylabel('Number of births')
plt.xlabel('Gender');

# %%
# same data, but a horizontal plot this time

labels = ['Female', 'Male']
values = [345, 435]

plt.barh(labels, values)
# We can also change, for example, the text direction of the pole labels to save some space
plt.xticks(rotation=45)
plt.ylabel('Number of births')
plt.xlabel('Gender');

# %% [markdown]
# ### 2.5 Histogram

# %% [markdown]
# > **Docs**: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html

# %% [markdown]
# **Listing 11**

# %%
# sample data (from standard normal distribution)
x = np.random.randn(10000)

# `bins` specifies the number of “bins” (i.e., bars) into which values from the `x` vector will be assigned
# `facekolor` specifies the color of the bars
# `alpha` is the transparency level of the plot
# `density` specifies whether the sum of the values will be normalized to the probability distribution (i.e., the range 0 to 1)
plt.hist(x, bins=50, facecolor='g', alpha=0.75, density=True)
# plt.hist(x, bins=50, facecolor='g', alpha=0.75)

plt.xlabel('Values')
plt.ylabel('Probability')
plt.title('Histogram')
# showing the grid
plt.grid(True)

# %% [markdown]
# ### 2.6 Pie chart

# %% [markdown]
# > **Docs**: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pie.html

# %% [markdown]
# **Listing 12**

# %%
players = ['Messi', 'Suarez', 'Dembele', 'Coutinho']
goals = [48, 25, 13, 11]

# firtst version of the plot
wedges, texts, autotexts = plt.pie(goals, labels=players,
                                   autopct=lambda pct: "{:.1f}%".format(pct), textprops=dict(color="black"))
plt.setp(autotexts, size=12, weight="bold")
plt.title("First version of the plot")
plt.legend(title='Players')
plt.show()

# second version of the plot
def prepare_label(pct, br):
    absolute = int(np.ceil(pct / 100. * np.sum(br)))
    return "{:.1f}% \n({}/{})".format(pct, absolute, sum(goals))


wedges, texts, autotexts = plt.pie(goals, labels=players,
                                   autopct=lambda pct: prepare_label(pct, goals), textprops=dict(color="black"))
plt.setp(autotexts, size=12, weight="bold")
plt.title("Second version of the plot")

# you can learn more about available legend parameters from docs:
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html
plt.legend(title='Players', loc='best');

# %% [markdown]
# ### 3. Plotting directly from pandas DataFrame

# %% [markdown]
# The matplotlib library is a low-level library compared to the libraries that will be introduced in future classes (seaborn, bokeh, plotly) and requires a bit more work when preparing and selecting data for a plot. The example will be based on the data from the `orders.csv` file.

# %%
import pandas as pd

df_ord = pd.read_csv(r'https://raw.githubusercontent.com/kropiak/__swps_data_analysis_2026/refs/heads/main/lab_06/data/orders.csv', sep=';')
df_ord.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 799 entries, 0 to 798
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     799 non-null    object
#  1   Seller      799 non-null    object
#  2   OrderDate   799 non-null    object
#  3   OrderId     799 non-null    int64
#  4   OrderValue  799 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 31.3+ KB

# %%
# basic line plot for a single column
df_ord['OrderValue'].plot()
# Out:
# <Axes: >

# %%
# or passing a pandas Series to a plot function
plt.plot(df_ord['OrderValue'])

# %%
# Let’s now consider an example in which we want to display two data series (two lines on a single chart) for each country individually
plt.plot(df_ord[df_ord['Country'] == 'Polska']['OrderValue'])
plt.plot(df_ord[df_ord['Country'] == 'Niemcy']['OrderValue'])
plt.legend(['Polska','Niemcy'])

# %%
# Now we'd like to do the same thing, but for each year (and country) separately, calculating the total revenue
# The easiest way is to prepare the data in the form of a grouped table with aggregation

# Step 1 – We’ll convert the Order Date column to a datetime type, which will make it much easier to work with the date components (and, for example, group by year, month, etc.)
df_ord['OrderDate'] = pd.to_datetime(df_ord['OrderDate'])
df_ord.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 799 entries, 0 to 798
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     799 non-null    object
#  1   Seller      799 non-null    object
#  2   OrderDate   799 non-null    datetime64[ns]
#  3   OrderId     799 non-null    int64
#  4   OrderValue  799 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 31.3+ KB

# %%
# Step 2 - We group the data and calculate the total for each group (i.e., country and year)
df_ord_sum_by_year = df_ord.groupby([df_ord['OrderDate'].dt.year, 'Country']).agg({'OrderValue': ['sum']})
df_ord_sum_by_year
# Out:
#                   OrderValue
#                          sum
# OrderDate Country
# 2003      Niemcy   136002.99
#           Polska    57313.55
# 2004      Niemcy   452347.15
#           Polska   156843.61
# 2005      Niemcy   306646.35
#           Polska   119173.75

# %%
# Step 3 - Plot
# Let's just try plotting the data for the ‘OrderValue’ and ‘sum’ columns (since we have a multi-index here)
fig = plt.figure(figsize=(10,8))
df_ord_sum_by_year[('OrderValue', 'sum')].plot()

# It doesn't quite look the way we want it to (we want two separate series for the country, with the year on the x-axis)
# Out:
# <Axes: xlabel='OrderDate,Country'>

# %%
# So let's try doing this separately
# What indexes do we have in the frame?
df_ord_sum_by_year.index
# Out:
# MultiIndex([(2003, 'Niemcy'),
#             (2003, 'Polska'),
#             (2004, 'Niemcy'),
#             (2004, 'Polska'),
#             (2005, 'Niemcy'),
#             (2005, 'Polska')],
#            names=['OrderDate', 'Country'])

# %%
# single data point looks like follows
df_ord_sum_by_year.loc[2003,'Polska']
# Out:
# OrderValue  sum    57313.55
# Name: (2003, Polska), dtype: float64

# %%
# Extracting data from such a frame is quite tricky
# Resetting the index might help
df_ord_sum_by_year_2 = df_ord_sum_by_year.reset_index()
df_ord_sum_by_year_2
# Out:
#   OrderDate Country OrderValue
#                            sum
# 0      2003  Niemcy  136002.99
# 1      2003  Polska   57313.55
# 2      2004  Niemcy  452347.15
# 3      2004  Polska  156843.61
# 4      2005  Niemcy  306646.35
# 5      2005  Polska  119173.75

# %%
# now it should be easier
x = df_ord_sum_by_year_2['OrderDate'].unique()
plt.xticks(df_ord_sum_by_year_2['OrderDate'].unique())
plt.xlabel('Year')
plt.plot(x, df_ord_sum_by_year_2[df_ord_sum_by_year_2['Country'] == 'Polska'][('OrderValue','sum')])
plt.plot(x, df_ord_sum_by_year_2[df_ord_sum_by_year_2['Country'] == 'Niemcy'][('OrderValue','sum')])

# %%
# To organize the data frame so that it's even easier to access the data series, we'll use the unstack() function
df_ord_sum_by_year.unstack()
# Out:
#           OrderValue
#                  sum
# Country       Niemcy     Polska
# OrderDate
# 2003       136002.99   57313.55
# 2004       452347.15  156843.61
# 2005       306646.35  119173.75

# %%
df_ord_sum_by_year_unstacked = df_ord_sum_by_year.unstack()
df_ord_sum_by_year_unstacked.plot()
plt.legend([col[-1] for col in df_ord_sum_by_year_unstacked.columns])

# %%
# adjusting the x axis
plt.xticks(df_ord_sum_by_year_unstacked.index)
plt.plot(df_ord_sum_by_year_unstacked)
plt.legend(df_ord_sum_by_year_unstacked.columns)

# %% [markdown]
# ### 4. Tasks

# %% [markdown]
# **Task 1**
#
# Plot a line graph of the function `f(x) = 1/x for x ∈ [1, 20]`. Add a label to the graph line and display a legend. Add appropriate labels to the graph axes (`x`, `f(x)`) and set the range for both axes to (0, 1) and (1, the length of the vector x).
#
# **Task 2**
#
# Using the dataset [orders.csv](./data/orders.csv), prepare and display the data as a line graph showing the total orders for each seller from Poland in 2004, grouped by month (follow the example from point 3 of this lab). Each graph is a line for a given seller, and the x-axis represents the months of 2004. Remember that you can iterate through a grouped pandas dataframe.
#
# **Task 3**
#
# Using the pandas library, load the dataset on [child births](./data/names.xlsx) (in the column `Gender` - `K` stands for female - `kobieta` in Polish) and prepare the following charts:
# * 3.1 - a bar chart showing the number of girls and boys born over the entire period.
# * 3.2 - a line chart with two lines, one for the number of girls born and one for the number of boys born for each year separately. That is, y is the number of girls or boys born (two lines), and x is the year.
# * 3.3 - a bar chart showing the total number of children born each year.
#
# Add appropriate labels to the charts. Set different colors for the charts.
#
# **Task 4**
#
# Using the Iris dataset (https://archive.ics.uci.edu/ml/ datasets/iris), generate a scatter plot where the x-vector represents the `sepal length` and the y-vector represents the `sepal width`. Add a color palette `c` as shown in Listing 7, and let the parameter `s` be the absolute value of the difference between the values of the individual elements of the x and y vectors. Use the pandas library to store the dataset.
#
# **Task 5**
#
# Using the [orders.csv](./data/orders.csv) file, calculate the total order amounts for each seller and display a pie chart showing each seller’s percentage share of the total order amount. Search online for how to add a shadow to such a chart and how the `explode` attribute of this chart works. Display the basic chart, the chart with a shadow, and the chart with one element having the `explode` attribute enabled.
#
# **Task 6**
#
# You may need to install the openpyxl library by running the following code in a cell: `!pip install openpyxl`
#
# Using the matplotlib gallery and [example](https://matplotlib.org/stable/gallery/misc/packed_bubbles.html#sphx-glr-gallery-misc-packed-bubbles-py), try to plot the 10 most populous countries in the world in 2017 using the data in the [people](./data/people.xlsx) file.

# %% [markdown]
# ### Solutions

# %% [markdown]
# # #### Qicheng SUn。 82857。  Task 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

x = np.arange(1, 21)
y = 1 / x

plt.plot(x, y, label='f(x) = 1/x')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.axis([1, len(x), 0, 1]);

# %% [markdown]
# #### Task 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_ord = pd.read_csv('/content/data/orders.csv', sep=';')
df_ord['OrderDate'] = pd.to_datetime(df_ord['OrderDate'])

df_pl_2004 = df_ord[
    (df_ord['Country'] == 'Polska') & (df_ord['OrderDate'].dt.year == 2004)
]

df_monthly = (
    df_pl_2004
    .groupby([df_pl_2004['OrderDate'].dt.month, 'Seller'])['OrderValue']
    .sum()
    .reset_index()
)
df_monthly.columns = ['Month', 'Seller', 'OrderValue']

plt.figure(figsize=(10, 6))
for seller, group in df_monthly.groupby('Seller'):
    plt.plot(group['Month'], group['OrderValue'], marker='o', label=seller)

plt.xticks(range(1, 13))
plt.xlabel('Month')
plt.ylabel('Total order value')
plt.title('Total orders by seller from Poland in 2004')
plt.legend()
plt.grid(True, alpha=0.3);

# %% [markdown]
# #### Task 3

# %%
import pandas as pd
import matplotlib.pyplot as plt

names = pd.read_excel('/content/data/names.xlsx')

# 3.1 - bar chart: girls vs boys over the entire period
gender_totals = names.groupby('Gender')['Count'].sum()
plt.figure(figsize=(6, 4))
plt.bar(['Girls (K)', 'Boys (M)'], [gender_totals['K'], gender_totals['M']],
        color=['hotpink', 'steelblue'])
plt.xlabel('Gender')
plt.ylabel('Number of births')
plt.title('Number of girls and boys born over the entire period')
plt.show()

# 3.2 - line chart: girls and boys per year
yearly_gender = names.groupby(['Year', 'Gender'])['Count'].sum().unstack(fill_value=0)
plt.figure(figsize=(10, 6))
plt.plot(yearly_gender.index, yearly_gender['K'], label='Girls', color='hotpink', marker='o')
plt.plot(yearly_gender.index, yearly_gender['M'], label='Boys', color='steelblue', marker='o')
plt.xlabel('Year')
plt.ylabel('Number of births')
plt.title('Number of girls and boys born per year')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# 3.3 - bar chart: total children per year
yearly_total = names.groupby('Year')['Count'].sum()
plt.figure(figsize=(10, 6))
plt.bar(yearly_total.index, yearly_total.values, color='seagreen')
plt.xlabel('Year')
plt.ylabel('Number of births')
plt.title('Total number of children born each year');

# %% [markdown]
# #### Task 4

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

iris = pd.read_csv(
    'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',
    header=None,
    names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
)

c = iris['species'].astype('category').cat.codes
s = np.abs(iris['sepal_length'] - iris['sepal_width']) * 100

plt.figure(figsize=(8, 6))
plt.scatter(iris['sepal_length'], iris['sepal_width'], c=c, s=s, alpha=0.7)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.title('Iris dataset: sepal length vs sepal width');

# %% [markdown]
# #### Task 5

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_ord = pd.read_csv('./data/orders.csv', sep=';')
seller_totals = df_ord.groupby('Seller')['OrderValue'].sum().sort_values(ascending=False)

labels = seller_totals.index.tolist()
sizes = seller_totals.values

# basic pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('Seller share of total order amount (basic)')
plt.show()

# pie chart with shadow
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('Seller share of total order amount (with shadow)')
plt.show()

# pie chart with explode on the largest seller
explode = [0.1] + [0] * (len(sizes) - 1)
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', explode=explode)
plt.title('Seller share of total order amount (with explode)');

# %% [markdown]
# #### Task 6

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

people = pd.read_excel('/content/data/people.xlsx')
top10 = people.nlargest(10, 2017)


class BubbleChart:
    def __init__(self, area, bubble_spacing=0):
        area = np.asarray(area)
        r = np.sqrt(area / np.pi)

        self.bubble_spacing = bubble_spacing
        self.bubbles = np.ones((len(area), 4))
        self.bubbles[:, 2] = r
        self.bubbles[:, 3] = area
        self.maxstep = 2 * self.bubbles[:, 2].max() + self.bubble_spacing
        self.step_dist = self.maxstep / 2

        length = np.ceil(np.sqrt(len(self.bubbles)))
        grid = np.arange(length) * self.maxstep
        gx, gy = np.meshgrid(grid, grid)
        self.bubbles[:, 0] = gx.flatten()[:len(self.bubbles)]
        self.bubbles[:, 1] = gy.flatten()[:len(self.bubbles)]
        self.com = self.center_of_mass()

    def center_of_mass(self):
        return np.average(self.bubbles[:, :2], axis=0, weights=self.bubbles[:, 3])

    def center_distance(self, bubble, bubbles):
        return np.hypot(bubble[0] - bubbles[:, 0], bubble[1] - bubbles[:, 1])

    def outline_distance(self, bubble, bubbles):
        center_distance = self.center_distance(bubble, bubbles)
        return center_distance - bubble[2] - bubbles[:, 2] - self.bubble_spacing

    def check_collisions(self, bubble, bubbles):
        distance = self.outline_distance(bubble, bubbles)
        return len(distance[distance < 0])

    def collides_with(self, bubble, bubbles):
        distance = self.outline_distance(bubble, bubbles)
        return np.argmin(distance, keepdims=True)

    def collapse(self, n_iterations=50):
        for _ in range(n_iterations):
            moves = 0
            for i in range(len(self.bubbles)):
                rest_bub = np.delete(self.bubbles, i, 0)
                dir_vec = self.com - self.bubbles[i, :2]
                dir_vec = dir_vec / np.sqrt(dir_vec.dot(dir_vec))
                new_point = self.bubbles[i, :2] + dir_vec * self.step_dist
                new_bubble = np.append(new_point, self.bubbles[i, 2:4])

                if not self.check_collisions(new_bubble, rest_bub):
                    self.bubbles[i, :] = new_bubble
                    self.com = self.center_of_mass()
                    moves += 1
                else:
                    for colliding in self.collides_with(new_bubble, rest_bub):
                        dir_vec = rest_bub[colliding, :2] - self.bubbles[i, :2]
                        dir_vec = dir_vec / np.sqrt(dir_vec.dot(dir_vec))
                        orth = np.array([dir_vec[1], -dir_vec[0]])
                        new_point1 = self.bubbles[i, :2] + orth * self.step_dist
                        new_point2 = self.bubbles[i, :2] - orth * self.step_dist
                        dist1 = self.center_distance(self.com, np.array([new_point1]))
                        dist2 = self.center_distance(self.com, np.array([new_point2]))
                        new_point = new_point1 if dist1 < dist2 else new_point2
                        new_bubble = np.append(new_point, self.bubbles[i, 2:4])
                        if not self.check_collisions(new_bubble, rest_bub):
                            self.bubbles[i, :] = new_bubble
                            self.com = self.center_of_mass()

            if moves / len(self.bubbles) < 0.1:
                self.step_dist = self.step_dist / 2

    def plot(self, ax, labels, colors):
        for i in range(len(self.bubbles)):
            circ = plt.Circle(self.bubbles[i, :2], self.bubbles[i, 2], color=colors[i])
            ax.add_patch(circ)
            ax.text(
                *self.bubbles[i, :2],
                labels[i],
                horizontalalignment='center',
                verticalalignment='center',
                fontsize=8,
            )


labels = top10['Country'].tolist()
areas = top10[2017].values
colors = plt.cm.tab10(np.linspace(0, 1, len(labels)))

bubble_chart = BubbleChart(area=areas, bubble_spacing=0.1)
bubble_chart.collapse()

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(aspect='equal'))
bubble_chart.plot(ax, labels, colors)
ax.axis('off')
ax.relim()
ax.autoscale_view()
ax.set_title('10 most populous countries in the world in 2017');

# %% [markdown]
# **Interative plot example**

# %%
# !pip install ipympl

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider

# data preparation
x = np.linspace(-10, 10, 1000)
init_amplitude = 1.0
init_frequency = 1.0
init_phase = 0.0

def sine_wave(x, amp, freq, phase):
    return amp * np.sin(freq * x + phase)

# main plot window
fig, ax = plt.subplots(figsize=(8, 6))
plt.subplots_adjust(bottom=0.35) # space for sliders at the bottom
line, = ax.plot(x, sine_wave(x, init_amplitude, init_frequency, init_phase), lw=2)
ax.set_ylim(-5, 5)
ax.set_xlim(-10, 10)
ax.grid(True)
ax.set_title('Interactive plot')
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')

# configuring axis for sliders (x, y, width, height)
ax_amp = plt.axes([0.15, 0.2, 0.65, 0.03])
ax_freq = plt.axes([0.15, 0.1, 0.65, 0.03])
ax_phase = plt.axes([0.15, 0.0, 0.65, 0.03])

# sliders
slider_amp = Slider(ax_amp, 'Aplitude', 0.1, 5.0, valinit=init_amplitude)
slider_freq = Slider(ax_freq, 'Frequency', 0.1, 5.0, valinit=init_frequency)
slider_phase = Slider(ax_phase, 'Phase', -np.pi, np.pi, valinit=init_phase)

# function that updated plot after slider changes his state
def update(val):
    amp = slider_amp.val
    freq = slider_freq.val
    phase = slider_phase.val
    line.set_ydata(sine_wave(x, amp, freq, phase))
    fig.canvas.draw_idle()

# connecting events with sliders
slider_amp.on_changed(update)
slider_freq.on_changed(update)
slider_phase.on_changed(update)

plt.show()
# Out:
# <div id='06694091-3607-4dc6-8ec4-dc525df22315'></div>
