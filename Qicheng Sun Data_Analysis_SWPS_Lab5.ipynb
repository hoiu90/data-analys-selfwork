# %% [markdown]
# # Lab 5.
#
# Qicheng Sun

# %% [markdown]
# # 1. Data selection
#
# While statistics for an entire series or dataframe are useful, we are often interested in various subsets of data and their properties, which requires understanding (including by analogy with subsets we have already examined) the mechanisms for retrieving and filtering data in pandas. First, however, we will load the necessary data.
#
# In the examples below, you should update the data path to match your local file storage structure.

# %%
import pandas as pd
import os

# %%
# if the data folder is inside the same folder as your notebook
DATAPATH = '/content/loan_data.csv'

# %%
# link to the original dataset: https://www.kaggle.com/datasets/udaymalviya/bank-loan-data
df = pd.read_csv(os.path.join(DATAPATH, '/content/loan_data.csv'))

# %%
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0         561.0
# 1                 0.08                         2.0         504.0
# 2                 0.44                         3.0         635.0
# 3                 0.44                         2.0         675.0
# 4                 0.53                         4.0         586.0
#
#   previous_loan_defaults_on_file  loan_status
# 0                             No          1.0
# 1                            Yes          0.0
# 2                             No          1.0
# 3                             No          1.0
# 4                             No          1.0

# %% [markdown]
# ## 1.1 Selecting columns from pandas dataframe

# %%
# single column selection - we provide a name for a column as we search for a value in dictionary
# by providing a key name
df['person_gender']
# Out:
# 0        female
# 1        female
# 2        female
# 3        female
# 4          male
#           ...
# 26252    female
# 26253    female
# 26254    female
# 26255    female
# 26256      male
# Name: person_gender, Length: 26257, dtype: object

# %%
# selecting many columns is also possible by providing a list of column names
df[['person_gender','person_education']]
# Out:
#       person_gender person_education
# 0            female           Master
# 1            female      High School
# 2            female      High School
# 3            female         Bachelor
# 4              male           Master
# ...             ...              ...
# 26252        female      High School
# 26253        female         Bachelor
# 26254        female         Bachelor
# 26255        female         Bachelor
# 26256          male         Bachelor
#
# [26257 rows x 2 columns]

# %%
# We can also access data in a column using the dot operator
# depending on whether the column names contain whitespace or not
df.person_gender
# Out:
# 0        female
# 1        female
# 2        female
# 3        female
# 4          male
#           ...
# 26252    female
# 26253    female
# 26254    female
# 26255    female
# 26256      male
# Name: person_gender, Length: 26257, dtype: object

# %%
# after selecting single (pandas Series) or multiple columns (pandas dataFrame) part we
# can use indexing or slicing to get ROWS that we are interested in
df['person_gender'][:5]
# Out:
# 0    female
# 1    female
# 2    female
# 3    female
# 4      male
# Name: person_gender, dtype: object

# %%
df[['person_gender','person_education']][:5]
# Out:
#   person_gender person_education
# 0        female           Master
# 1        female      High School
# 2        female      High School
# 3        female         Bachelor
# 4          male           Master

# %% [markdown]
# ## 1.2 Selecting data using `.loc`, `.iloc`, and mapping with a boolean array
#
# `.loc` uses label-based indexing, but you can also pass a boolean array. Labels refer to the values in the index column of a pandas series or pandas DataFrame, or the column names in a pandas DataFrame.

# %%
# as pandas DataFrame is a two dimensional data type - we have two dimensions to provide indexes or slices for
# data selection
df.loc[:, 'person_gender']
# Out:
# 0        female
# 1        female
# 2        female
# 3        female
# 4          male
#           ...
# 26252    female
# 26253    female
# 26254    female
# 26255    female
# 26256      male
# Name: person_gender, Length: 26257, dtype: object

# %%
# We can also specify a value for only one dimension
# Here, we're looking for rows (default axis) where the “index” column has a value of 1, 2, or 3
df.loc[[1,2,3]]
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 1                 0.08                         2.0         504.0
# 2                 0.44                         3.0         635.0
# 3                 0.44                         2.0         675.0
#
#   previous_loan_defaults_on_file  loan_status
# 1                            Yes          0.0
# 2                             No          1.0
# 3                             No          1.0

# %%
df.loc[:5, ['person_gender', 'person_income']]
# Out:
#   person_gender  person_income
# 0        female        71948.0
# 1        female        12282.0
# 2        female        12438.0
# 3        female        79753.0
# 4          male        66135.0
# 5        female        12951.0

# %%
# Note that the value for the first dimension (loc) is the actual value in the index column,
# not the index number of the elements in that index.
# Below is an example where the index has been changed to values starting from 1.
df.index = range(1, df.shape[0] + 1)

# %%
df[:5]
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 1        22.0        female           Master        71948.0               0
# 2        21.0        female      High School        12282.0               0
# 3        25.0        female      High School        12438.0               3
# 4        23.0        female         Bachelor        79753.0               0
# 5        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 1                  RENT    35000.0    PERSONAL          16.02
# 2                   OWN     1000.0   EDUCATION          11.14
# 3              MORTGAGE     5500.0     MEDICAL          12.87
# 4                  RENT    35000.0     MEDICAL          15.23
# 5                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 1                 0.49                         3.0         561.0
# 2                 0.08                         2.0         504.0
# 3                 0.44                         3.0         635.0
# 4                 0.44                         2.0         675.0
# 5                 0.53                         4.0         586.0
#
#   previous_loan_defaults_on_file  loan_status
# 1                             No          1.0
# 2                            Yes          0.0
# 3                             No          1.0
# 4                             No          1.0
# 5                             No          1.0

# %%
# now we are checking how loc works with the same parameters as iloc
df.loc[:5, ['person_gender', 'person_income']]
# Out:
#   person_gender  person_income
# 1        female        71948.0
# 2        female        12282.0
# 3        female        12438.0
# 4        female        79753.0
# 5          male        66135.0

# %% [markdown]
# **WARNING!**
#
# Indexing using labels is performed with the stop value included, which is different from how classic slices work in Python!

# %% [markdown]
# Indexing with `.iloc` is similar to `.loc`, but here the letter `i` represents an index, so instead of column and row labels, we specify indices.

# %%
# row indexes: 0-4, column indexes: 2 and 3
df.iloc[:5, 2:4]
# Out:
#   person_education  person_income
# 1           Master        71948.0
# 2      High School        12282.0
# 3      High School        12438.0
# 4         Bachelor        79753.0
# 5           Master        66135.0

# %%
# Just like with the NumPy library, we can also manipulate the data in these areas, such as swapping the order of the columns
# although this isn’t usually necessary, since we can retrieve data from the frame in any column order
# Here’s the column order: third, second, and fourth columns (remember that indexing starts at 0?)
df.iloc[:, [2,1, 3]]
# Out:
#       person_education person_gender  person_income
# 1               Master        female        71948.0
# 2          High School        female        12282.0
# 3          High School        female        12438.0
# 4             Bachelor        female        79753.0
# 5               Master          male        66135.0
# ...                ...           ...            ...
# 26253      High School        female        91131.0
# 26254         Bachelor        female        75625.0
# 26255         Bachelor        female       120932.0
# 26256         Bachelor        female        68809.0
# 26257         Bachelor          male        76472.0
#
# [26257 rows x 3 columns]

# %%
# However, if we wanted to reorder them in the original grid, we could, for example, use the vector
# of the current column names from the .columns property
df.columns
# Out:
# Index(['person_age', 'person_gender', 'person_education', 'person_income',
#        'person_emp_exp', 'person_home_ownership', 'loan_amnt', 'loan_intent',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length',
#        'credit_score', 'previous_loan_defaults_on_file', 'loan_status'],
#       dtype='object')

# %%
# Let's say we want to swap columns 2 and 3
# For simplicity, we'll store the values of these labels in a Python list
old_columns = list(df.columns)
new_column_order = old_columns[:1] + old_columns[2:0:-1] + old_columns[3:]
new_column_order
# Out:
# ['person_age',
#  'person_education',
#  'person_gender',
#  'person_income',
#  'person_emp_exp',
#  'person_home_ownership',
#  'loan_amnt',
#  'loan_intent',
#  'loan_int_rate',
#  'loan_percent_income',
#  'cb_person_cred_hist_length',
#  'credit_score',
#  'previous_loan_defaults_on_file',
#  'loan_status']

# %%
# Overwrite the variable with the original data frame, a new data frame with a different column order
df = df.loc[:, new_column_order]

# %%
df.head()
# Out:
#    person_age person_education person_gender  person_income  person_emp_exp  \
# 1        22.0           Master        female        71948.0               0
# 2        21.0      High School        female        12282.0               0
# 3        25.0      High School        female        12438.0               3
# 4        23.0         Bachelor        female        79753.0               0
# 5        24.0           Master          male        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 1                  RENT    35000.0    PERSONAL          16.02
# 2                   OWN     1000.0   EDUCATION          11.14
# 3              MORTGAGE     5500.0     MEDICAL          12.87
# 4                  RENT    35000.0     MEDICAL          15.23
# 5                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 1                 0.49                         3.0         561.0
# 2                 0.08                         2.0         504.0
# 3                 0.44                         3.0         635.0
# 4                 0.44                         2.0         675.0
# 5                 0.53                         4.0         586.0
#
#   previous_loan_defaults_on_file  loan_status
# 1                             No          1.0
# 2                            Yes          0.0
# 3                             No          1.0
# 4                             No          1.0
# 5                             No          1.0

# %% [markdown]
# **Selecting Data Using Boolean Value Tables**
#
# This operation is typically used in data filtering, where a condition is applied to select data from a frame or series. Here, we can use the operators `|` (logical OR), `&` (logical AND), and `~` for negation.

# %%
# returned type - a numpy array of boolean types (a mapping)
print(df['person_gender'] == 'female')

# now we apply the mapping to the data
df[df['person_gender'] == 'female']
# Out:
# 1         True
# 2         True
# 3         True
# 4         True
# 5        False
#          ...
# 26253     True
# 26254     True
# 26255     True
# 26256     True
# 26257    False
# Name: person_gender, Length: 26257, dtype: bool
#        person_age person_education person_gender  person_income  \
# 1            22.0           Master        female        71948.0
# 2            21.0      High School        female        12282.0
# 3            25.0      High School        female        12438.0
# 4            23.0         Bachelor        female        79753.0
# 6            21.0      High School        female        12951.0
# ...           ...              ...           ...            ...
# 26250        31.0         Bachelor        female        90664.0
# 26253        29.0      High School        female        91131.0
# 26254        28.0         Bachelor        female        75625.0
# 26255        27.0         Bachelor        female       120932.0
# 26256        27.0         Bachelor        female        68809.0
#
#        person_emp_exp person_home_ownership  loan_amnt      loan_intent  \
# 1                   0                  RENT    35000.0         PERSONAL
# 2                   0                   OWN     1000.0        EDUCATION
# 3                   3              MORTGAGE     5500.0          MEDICAL
# 4                   0                  RENT    35000.0          MEDICAL
# 6                   0                   OWN     2500.0          VENTURE
# ...               ...                   ...        ...              ...
# 26250               8              MORTGAGE    10000.0          MEDICAL
# 26253               8              MORTGAGE    15000.0          MEDICAL
# 26254               7                  RENT    14000.0          VENTURE
# 26255               1              MORTGAGE     3000.0          VENTURE
# 26256               3                  RENT    14000.0  HOMEIMPROVEMENT
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 1              16.02                 0.49                         3.0
# 2              11.14                 0.08                         2.0
# 3              12.87                 0.44                         3.0
# 4              15.23                 0.44                         2.0
# 6               7.14                 0.19                         2.0
# ...              ...                  ...                         ...
# 26250          15.58                 0.11                         6.0
# 26253          15.33                 0.16                        10.0
# 26254          10.99                 0.19                        10.0
# 26255          12.84                 0.02                        10.0
# 26256          13.87                 0.20                         8.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 1             561.0                             No          1.0
# 2             504.0                            Yes          0.0
# 3             635.0                             No          1.0
# 4             675.0                             No          1.0
# 6             532.0                             No          1.0
# ...             ...                            ...          ...
# 26250         687.0                             No          1.0
# 26253         590.0                             No          1.0
# 26254         647.0                             No          0.0
# 26255         695.0                            Yes          0.0
# 26256         656.0                             No          1.0
#
# [11773 rows x 14 columns]

# %%
# mapping with two conditions (& - this is a logical AND operator)
(df['loan_amnt'] > 10000) & (df['person_income'] < 50000)
# Out:
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 26253    False
# 26254    False
# 26255    False
# 26256    False
# 26257    False
# Length: 26257, dtype: bool

# %%
# and now the data by applying the mapping
df[(df['loan_amnt'] > 10000) & (df['person_income'] < 50000)]
# Out:
#        person_age person_education person_gender  person_income  \
# 461          24.0        Associate          male        22684.0
# 494          23.0         Bachelor          male        43042.0
# 536          22.0      High School          male        38473.0
# 544          21.0      High School          male        42536.0
# 547          26.0         Bachelor        female        48929.0
# ...           ...              ...           ...            ...
# 26117        33.0        Associate          male        40597.0
# 26131        30.0         Bachelor        female        28849.0
# 26143        28.0        Associate        female        45584.0
# 26147        28.0      High School          male        47754.0
# 26176        31.0         Bachelor        female        39461.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 461                 0                   OWN    13000.0           PERSONAL
# 494                 1                  RENT    22250.0  DEBTCONSOLIDATION
# 536                 0                  RENT    21250.0  DEBTCONSOLIDATION
# 544                 0                  RENT    21000.0            VENTURE
# 547                 6                  RENT    21000.0            MEDICAL
# ...               ...                   ...        ...                ...
# 26117               9                  RENT    13800.0            VENTURE
# 26131               6                  RENT    14000.0            VENTURE
# 26143               5                  RENT    14000.0  DEBTCONSOLIDATION
# 26147               8                  RENT    14000.0          EDUCATION
# 26176               8                   OWN    12375.0            VENTURE
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 461             7.88                 0.57                         3.0
# 494            12.69                 0.52                         3.0
# 536            12.42                 0.55                         3.0
# 544            12.53                 0.49                         4.0
# 547             6.54                 0.43                         4.0
# ...              ...                  ...                         ...
# 26117          13.47                 0.34                         5.0
# 26131           7.88                 0.49                         6.0
# 26143          14.42                 0.31                        10.0
# 26147           7.90                 0.29                         8.0
# 26176           9.91                 0.31                         7.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 461           640.0                             No          1.0
# 494           678.0                             No          1.0
# 536           599.0                             No          1.0
# 544           687.0                             No          1.0
# 547           601.0                             No          1.0
# ...             ...                            ...          ...
# 26117         640.0                             No          1.0
# 26131         614.0                             No          1.0
# 26143         684.0                             No          1.0
# 26147         584.0                             No          1.0
# 26176         552.0                            Yes          0.0
#
# [1126 rows x 14 columns]

# %%
# and now we're completing this data by using the same condition and its negation
# an additional parenthesis has been added
df[~((df['loan_amnt'] > 10000) & (df['person_income'] < 50000))]
# Out:
#        person_age person_education person_gender  person_income  \
# 1            22.0           Master        female        71948.0
# 2            21.0      High School        female        12282.0
# 3            25.0      High School        female        12438.0
# 4            23.0         Bachelor        female        79753.0
# 5            24.0           Master          male        66135.0
# ...           ...              ...           ...            ...
# 26253        29.0      High School        female        91131.0
# 26254        28.0         Bachelor        female        75625.0
# 26255        27.0         Bachelor        female       120932.0
# 26256        27.0         Bachelor        female        68809.0
# 26257        32.0         Bachelor          male        76472.0
#
#        person_emp_exp person_home_ownership  loan_amnt      loan_intent  \
# 1                   0                  RENT    35000.0         PERSONAL
# 2                   0                   OWN     1000.0        EDUCATION
# 3                   3              MORTGAGE     5500.0          MEDICAL
# 4                   0                  RENT    35000.0          MEDICAL
# 5                   1                  RENT    35000.0          MEDICAL
# ...               ...                   ...        ...              ...
# 26253               8              MORTGAGE    15000.0          MEDICAL
# 26254               7                  RENT    14000.0          VENTURE
# 26255               1              MORTGAGE     3000.0          VENTURE
# 26256               3                  RENT    14000.0  HOMEIMPROVEMENT
# 26257               7                  RENT    14000.0        EDUCATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 1              16.02                 0.49                         3.0
# 2              11.14                 0.08                         2.0
# 3              12.87                 0.44                         3.0
# 4              15.23                 0.44                         2.0
# 5              14.27                 0.53                         4.0
# ...              ...                  ...                         ...
# 26253          15.33                 0.16                        10.0
# 26254          10.99                 0.19                        10.0
# 26255          12.84                 0.02                        10.0
# 26256          13.87                 0.20                         8.0
# 26257           6.00                  NaN                         NaN
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 1             561.0                             No          1.0
# 2             504.0                            Yes          0.0
# 3             635.0                             No          1.0
# 4             675.0                             No          1.0
# 5             586.0                             No          1.0
# ...             ...                            ...          ...
# 26253         590.0                             No          1.0
# 26254         647.0                             No          0.0
# 26255         695.0                            Yes          0.0
# 26256         656.0                             No          1.0
# 26257           NaN                            NaN          NaN
#
# [25131 rows x 14 columns]

# %%
# If we want to filter a column based on multiple values, it will be more useful and concise to
# use the isin() method
df['person_education'].isin(['Associate', 'High School'])
# Out:
# 1        False
# 2         True
# 3         True
# 4        False
# 5        False
#          ...
# 26253     True
# 26254    False
# 26255    False
# 26256    False
# 26257    False
# Name: person_education, Length: 26257, dtype: bool

# %%
# Filtering is also possible using a callable object,
# such as a built-in function or an anonymous function (lambda)
# Here are some examples

# Here, we first access the value `str` from this series, then apply the `startswith(‘D’)` method to each
# value in the series, which returns a Boolean array
map_1 = df['loan_intent'].str.startswith('D')

# Here's the same effect, but using `apply` (which maps something to each element of an iterable object) — here we map a function
# to each value in a given data series, and additionally pass the argument ‘D’ to the mapped function
map_2 = df['loan_intent'].apply(str.startswith, args='D')

# and yet another example - this time using anonymous function (lambda)
map_3 = df['loan_intent'].map(lambda x: x.startswith('D'))

map_1, map_2, map_3
# Out:
# (1        False
#  2        False
#  3        False
#  4        False
#  5        False
#           ...
#  26253    False
#  26254    False
#  26255    False
#  26256    False
#  26257    False
#  Name: loan_intent, Length: 26257, dtype: bool,
#  1        False
#  2        False
#  3        False
#  4        False
#  5        False
#           ...
#  26253    False
#  26254    False
#  26255    False
#  26256    False
#  26257    False
#  Name: loan_intent, Length: 26257, dtype: bool,
#  1        False
#  2        False
#  3        False
#  4        False
#  5        False
#           ...
#  26253    False
#  26254    False
#  26255    False
#  26256    False
#  26257    False
#  Name: loan_intent, Length: 26257, dtype: bool)

# %%
df[map_1]
# Out:
#        person_age person_education person_gender  person_income  \
# 16           23.0           Master        female       600891.0
# 19           23.0         Bachelor          male       136628.0
# 34           25.0      High School        female       368115.0
# 38           24.0      High School          male        78026.0
# 40           23.0      High School        female        86811.0
# ...           ...              ...           ...            ...
# 26205        27.0         Bachelor          male        58959.0
# 26214        32.0           Master        female       118426.0
# 26222        32.0         Bachelor        female       119435.0
# 26224        34.0      High School        female       119073.0
# 26243        28.0           Master        female       120238.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 16                  5              MORTGAGE    30000.0  DEBTCONSOLIDATION
# 19                  0                  RENT    35000.0  DEBTCONSOLIDATION
# 34                  3                  RENT    24250.0  DEBTCONSOLIDATION
# 38                  3                  RENT    30000.0  DEBTCONSOLIDATION
# 40                  0                  RENT    30000.0  DEBTCONSOLIDATION
# ...               ...                   ...        ...                ...
# 26205               6                  RENT    14000.0  DEBTCONSOLIDATION
# 26214              10              MORTGAGE     6000.0  DEBTCONSOLIDATION
# 26222              10              MORTGAGE     5400.0  DEBTCONSOLIDATION
# 26224              11              MORTGAGE     2500.0  DEBTCONSOLIDATION
# 26243               8              MORTGAGE     6500.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 16             10.65                 0.05                         3.0
# 19             18.25                 0.26                         4.0
# 34             13.85                 0.07                         3.0
# 38             14.54                 0.38                         3.0
# 40             11.01                 0.35                         4.0
# ...              ...                  ...                         ...
# 26205          13.79                 0.24                        10.0
# 26214           8.88                 0.05                        10.0
# 26222           9.38                 0.05                         6.0
# 26224          15.96                 0.02                        10.0
# 26243           5.99                 0.05                         6.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 16            670.0                            Yes          0.0
# 19            709.0                             No          1.0
# 34            567.0                            Yes          0.0
# 38            582.0                             No          1.0
# 40            602.0                             No          1.0
# ...             ...                            ...          ...
# 26205         619.0                             No          1.0
# 26214         663.0                             No          0.0
# 26222         710.0                             No          0.0
# 26224         643.0                            Yes          0.0
# 26243         672.0                             No          0.0
#
# [4224 rows x 14 columns]

# %%
# Let's consider a scenario where we're interested in records where, after subtracting the loan amount
# from income, the remaining amount is greater than 50,000

# We can calculate this fairly easily
print(df['person_income'] - df['loan_amnt'])

# now we can use it as a condition (mapping)
netto_income_mapping = (df['person_income'] - df['loan_amnt']) > 50000
print(netto_income_mapping)

# and apply to the real data
df[netto_income_mapping]

# Can this also be done using a lambda function?

# A lambda function receives a parameter for each value returned by the iterator for the iterable
# on which it is called. In the previous case, it was a single data series, so the anonymous function received
# a single value from the series. Now let’s try another example where the function receives multiple values.

# Here, the lambda function’s argument is the entire record from the data frame; we can index it in any way
# that was presented earlier
df.apply(lambda x: (x['person_income'] - x['loan_amnt']) > 50000, axis=1)
# Out:
# 1         36948.0
# 2         11282.0
# 3          6938.0
# 4         44753.0
# 5         31135.0
#            ...
# 26253     76131.0
# 26254     61625.0
# 26255    117932.0
# 26256     54809.0
# 26257     62472.0
# Length: 26257, dtype: float64
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 26253     True
# 26254     True
# 26255     True
# 26256     True
# 26257     True
# Length: 26257, dtype: bool
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 26253     True
# 26254     True
# 26255     True
# 26256     True
# 26257     True
# Length: 26257, dtype: bool

# %% [markdown]
# ## 1.3 Using `DataFrame.query`
#
# In addition to the examples shown above, there is also the `query` method, which can be easier to write when filtering large sets of elements.
#
# Examples in the documentation: https://pandas.pydata.org/docs/user_guide/indexing.html#the-query-method
#
# Here are a few examples.

# %%
df.query('person_income > 100000')
# Out:
#        person_age person_education person_gender  person_income  \
# 9            24.0        Associate        female       100684.0
# 11           22.0      High School        female       102985.0
# 13           23.0         Bachelor          male       114860.0
# 14           26.0           Master          male       130713.0
# 15           23.0        Associate        female       138998.0
# ...           ...              ...           ...            ...
# 26247        28.0      High School          male       120995.0
# 26249        33.0         Bachelor          male       121038.0
# 26251        32.0        Associate          male       121154.0
# 26252        34.0         Bachelor          male       121188.0
# 26255        27.0         Bachelor        female       120932.0
#
#        person_emp_exp person_home_ownership  loan_amnt      loan_intent  \
# 9                   3                  RENT    35000.0         PERSONAL
# 11                  0                  RENT    35000.0          VENTURE
# 13                  3                  RENT    35000.0          VENTURE
# 14                  0                  RENT    35000.0        EDUCATION
# 15                  0                  RENT    35000.0        EDUCATION
# ...               ...                   ...        ...              ...
# 26247               2              MORTGAGE    10000.0          VENTURE
# 26249              13              MORTGAGE     6000.0         PERSONAL
# 26251               8              MORTGAGE     7000.0  HOMEIMPROVEMENT
# 26252              13              MORTGAGE     9800.0         PERSONAL
# 26255               1              MORTGAGE     3000.0          VENTURE
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 9               8.90                 0.35                         2.0
# 11             10.37                 0.34                         4.0
# 13              7.90                 0.30                         2.0
# 14             18.39                 0.27                         4.0
# 15              7.90                 0.25                         4.0
# ...              ...                  ...                         ...
# 26247           5.42                 0.08                         8.0
# 26249          11.11                 0.05                         7.0
# 26251           7.14                 0.06                         9.0
# 26252           7.14                 0.08                         8.0
# 26255          12.84                 0.02                        10.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 9             544.0                             No          1.0
# 11            621.0                             No          1.0
# 13            573.0                             No          1.0
# 14            708.0                             No          1.0
# 15            583.0                             No          0.0
# ...             ...                            ...          ...
# 26247         650.0                             No          0.0
# 26249         684.0                             No          0.0
# 26251         620.0                             No          0.0
# 26252         723.0                             No          0.0
# 26255         695.0                            Yes          0.0
#
# [4766 rows x 14 columns]

# %%
# Here, too, we can use the operators &, |, and ~
# As a reminder
# & - logical AND
# | - logical OR
# ~ - negation
display(df.query('person_education == "Doctorate" & person_age > 40'))
# code below 'person_education == ["Doctorate", "Master"] works like isin(["Doctorate", "Master"])
df.query('person_education == ["Doctorate", "Master"] & person_age > 40')
# Out:
# Empty DataFrame
# Columns: [person_age, person_education, person_gender, person_income, person_emp_exp, person_home_ownership, loan_amnt, loan_intent, loan_int_rate, loan_percent_income, cb_person_cred_hist_length, credit_score, previous_loan_defaults_on_file, loan_status]
# Index: []
# Empty DataFrame
# Columns: [person_age, person_education, person_gender, person_income, person_emp_exp, person_home_ownership, loan_amnt, loan_intent, loan_int_rate, loan_percent_income, cb_person_cred_hist_length, credit_score, previous_loan_defaults_on_file, loan_status]
# Index: []

# %% [markdown]
# **Task 1**
# Rename the column loan_amnt to loan_amount

# %%
df.head(3)
# Out:
#    person_age person_education person_gender  person_income  person_emp_exp  \
# 1        22.0           Master        female        71948.0               0
# 2        21.0      High School        female        12282.0               0
# 3        25.0      High School        female        12438.0               3
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 1                  RENT    35000.0    PERSONAL          16.02
# 2                   OWN     1000.0   EDUCATION          11.14
# 3              MORTGAGE     5500.0     MEDICAL          12.87
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 1                 0.49                         3.0         561.0
# 2                 0.08                         2.0         504.0
# 3                 0.44                         3.0         635.0
#
#   previous_loan_defaults_on_file  loan_status
# 1                             No          1.0
# 2                            Yes          0.0
# 3                             No          1.0

# %%
# Renaming the column and updating the dataframe
df = df.rename(columns={'loan_amnt': 'loan_amount'})

# %% [markdown]
# **Task 2**
#
# From the data frame used in the examples (loan), display:
#
#  - a) only the columns person_gender, person_age, and person_income,
# - b) rows from 1000 through 2000 inclusive (this refers to consecutive rows in the dataset, not the index value),
# - c) even-numbered rows,
# - d) rows with an even value in the index column,
# - e) the first and last columns with one function call.

# %%
# a) Only specific columns
task_2a = df[['person_gender', 'person_age', 'person_income']]

# b) Rows 1000 through 2000 inclusive (consecutive rows/positional)
# Using .iloc is zero-based, so 1000:2001 gets the 1000th through 2000th records
task_2b = df.iloc[1000:2001]

# c) Even-numbered rows (positional 0, 2, 4...)
task_2c = df.iloc[::2]

# d) Rows with an even value in the actual index column
task_2d = df[df.index % 2 == 0]

# e) The first and last columns with one function call, fancy slicing shows copy
task_2e = df.iloc[:, [0, -1]]

# %%
task_2a
# Out:
#       person_gender  person_age  person_income
# 1            female        22.0        71948.0
# 2            female        21.0        12282.0
# 3            female        25.0        12438.0
# 4            female        23.0        79753.0
# 5              male        24.0        66135.0
# ...             ...         ...            ...
# 26253        female        29.0        91131.0
# 26254        female        28.0        75625.0
# 26255        female        27.0       120932.0
# 26256        female        27.0        68809.0
# 26257          male        32.0        76472.0
#
# [26257 rows x 3 columns]

# %%
task_2b
# Out:
#       person_age person_education person_gender  person_income  \
# 1001        23.0         Bachelor          male        30059.0
# 1002        24.0         Bachelor          male        68258.0
# 1003        21.0         Bachelor          male        60821.0
# 1004        25.0      High School          male        70432.0
# 1005        21.0         Bachelor        female        63842.0
# ...          ...              ...           ...            ...
# 1997        21.0           Master          male        37264.0
# 1998        24.0        Associate        female        36841.0
# 1999        24.0         Bachelor          male        37068.0
# 2000        22.0         Bachelor          male        37513.0
# 2001        23.0        Associate        female        36711.0
#
#       person_emp_exp person_home_ownership  loan_amount        loan_intent  \
# 1001               0              MORTGAGE       1375.0            MEDICAL
# 1002               2                  RENT      18000.0          EDUCATION
# 1003               0                  RENT      18000.0          EDUCATION
# 1004               6                  RENT      18000.0            VENTURE
# 1005               0                  RENT      18000.0            MEDICAL
# ...              ...                   ...          ...                ...
# 1997               0                  RENT      14000.0            MEDICAL
# 1998               4                  RENT      14000.0  DEBTCONSOLIDATION
# 1999               2              MORTGAGE       3075.0  DEBTCONSOLIDATION
# 2000               0                  RENT      14000.0            VENTURE
# 2001               0                  RENT      14000.0            MEDICAL
#
#       loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 1001          11.11                 0.05                         4.0
# 1002          13.48                 0.26                         3.0
# 1003          14.74                 0.30                         2.0
# 1004          11.01                 0.26                         4.0
# 1005          19.69                 0.28                         2.0
# ...             ...                  ...                         ...
# 1997          10.65                 0.38                         2.0
# 1998           7.90                 0.38                         2.0
# 1999          11.01                 0.08                         4.0
# 2000           6.99                 0.37                         4.0
# 2001          11.26                 0.38                         3.0
#
#       credit_score previous_loan_defaults_on_file  loan_status
# 1001         506.0                             No          1.0
# 1002         671.0                             No          1.0
# 1003         530.0                             No          1.0
# 1004         609.0                             No          1.0
# 1005         678.0                             No          1.0
# ...            ...                            ...          ...
# 1997         545.0                             No          1.0
# 1998         538.0                             No          1.0
# 1999         521.0                            Yes          0.0
# 2000         595.0                             No          1.0
# 2001         554.0                             No          1.0
#
# [1001 rows x 14 columns]

# %%
task_2c
# Out:
#        person_age person_education person_gender  person_income  \
# 1            22.0           Master        female        71948.0
# 3            25.0      High School        female        12438.0
# 5            24.0           Master          male        66135.0
# 7            26.0         Bachelor        female        93471.0
# 9            24.0        Associate        female       100684.0
# ...           ...              ...           ...            ...
# 26249        33.0         Bachelor          male       121038.0
# 26251        32.0        Associate          male       121154.0
# 26253        29.0      High School        female        91131.0
# 26255        27.0         Bachelor        female       120932.0
# 26257        32.0         Bachelor          male        76472.0
#
#        person_emp_exp person_home_ownership  loan_amount      loan_intent  \
# 1                   0                  RENT      35000.0         PERSONAL
# 3                   3              MORTGAGE       5500.0          MEDICAL
# 5                   1                  RENT      35000.0          MEDICAL
# 7                   1                  RENT      35000.0        EDUCATION
# 9                   3                  RENT      35000.0         PERSONAL
# ...               ...                   ...          ...              ...
# 26249              13              MORTGAGE       6000.0         PERSONAL
# 26251               8              MORTGAGE       7000.0  HOMEIMPROVEMENT
# 26253               8              MORTGAGE      15000.0          MEDICAL
# 26255               1              MORTGAGE       3000.0          VENTURE
# 26257               7                  RENT      14000.0        EDUCATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 1              16.02                 0.49                         3.0
# 3              12.87                 0.44                         3.0
# 5              14.27                 0.53                         4.0
# 7              12.42                 0.37                         3.0
# 9               8.90                 0.35                         2.0
# ...              ...                  ...                         ...
# 26249          11.11                 0.05                         7.0
# 26251           7.14                 0.06                         9.0
# 26253          15.33                 0.16                        10.0
# 26255          12.84                 0.02                        10.0
# 26257           6.00                  NaN                         NaN
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 1             561.0                             No          1.0
# 3             635.0                             No          1.0
# 5             586.0                             No          1.0
# 7             701.0                             No          1.0
# 9             544.0                             No          1.0
# ...             ...                            ...          ...
# 26249         684.0                             No          0.0
# 26251         620.0                             No          0.0
# 26253         590.0                             No          1.0
# 26255         695.0                            Yes          0.0
# 26257           NaN                            NaN          NaN
#
# [13129 rows x 14 columns]

# %%
task_2d
# Out:
#        person_age person_education person_gender  person_income  \
# 2            21.0      High School        female        12282.0
# 4            23.0         Bachelor        female        79753.0
# 6            21.0      High School        female        12951.0
# 8            24.0      High School        female        95550.0
# 10           21.0      High School        female        12739.0
# ...           ...              ...           ...            ...
# 26248        30.0         Bachelor          male        91144.0
# 26250        31.0         Bachelor        female        90664.0
# 26252        34.0         Bachelor          male       121188.0
# 26254        28.0         Bachelor        female        75625.0
# 26256        27.0         Bachelor        female        68809.0
#
#        person_emp_exp person_home_ownership  loan_amount      loan_intent  \
# 2                   0                   OWN       1000.0        EDUCATION
# 4                   0                  RENT      35000.0          MEDICAL
# 6                   0                   OWN       2500.0          VENTURE
# 8                   5                  RENT      35000.0          MEDICAL
# 10                  0                   OWN       1600.0          VENTURE
# ...               ...                   ...          ...              ...
# 26248               8              MORTGAGE       4800.0          MEDICAL
# 26250               8              MORTGAGE      10000.0          MEDICAL
# 26252              13              MORTGAGE       9800.0         PERSONAL
# 26254               7                  RENT      14000.0          VENTURE
# 26256               3                  RENT      14000.0  HOMEIMPROVEMENT
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 2              11.14                 0.08                         2.0
# 4              15.23                 0.44                         2.0
# 6               7.14                 0.19                         2.0
# 8              11.11                 0.37                         4.0
# 10             14.74                 0.13                         3.0
# ...              ...                  ...                         ...
# 26248          18.79                 0.05                         7.0
# 26250          15.58                 0.11                         6.0
# 26252           7.14                 0.08                         8.0
# 26254          10.99                 0.19                        10.0
# 26256          13.87                 0.20                         8.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 2             504.0                            Yes          0.0
# 4             675.0                             No          1.0
# 6             532.0                             No          1.0
# 8             585.0                             No          1.0
# 10            640.0                             No          1.0
# ...             ...                            ...          ...
# 26248         664.0                             No          1.0
# 26250         687.0                             No          1.0
# 26252         723.0                             No          0.0
# 26254         647.0                             No          0.0
# 26256         656.0                             No          1.0
#
# [13128 rows x 14 columns]

# %%
task_2e
# Out:
#        person_age  loan_status
# 1            22.0          1.0
# 2            21.0          0.0
# 3            25.0          1.0
# 4            23.0          1.0
# 5            24.0          1.0
# ...           ...          ...
# 26253        29.0          1.0
# 26254        28.0          0.0
# 26255        27.0          0.0
# 26256        27.0          1.0
# 26257        32.0          NaN
#
# [26257 rows x 2 columns]

# %% [markdown]
# **Task 3**
#
# From the same data frame, display data using filters (conditions):
#
# - a) only women with a Master or Bachelor degree and loans between 50,000 and 70,000,
# - b) all men with an education level other than Master and who own a home (person_home_ownership column = OWN),
# - c) all individuals with a loan_percent_income value between 0.4 and 0.6,
# - d) all loan amounts that are multiples of 10,000.

# %%
# a) Women with Master/Bachelor and loans between 50,000 and 70,000
task_3a = df.query("person_gender == 'female' & "
                   "person_education in ['Master', 'Bachelor'] & "
                   "loan_amount >= 50000 & loan_amount <= 70000")

# b) Men, education NOT Master, and own a home
task_3b = df.query("person_gender == 'male' & "
                   "person_education != 'Master' & "
                   "person_home_ownership == 'OWN'")

# c) loan_percent_income between 0.4 and 0.6
task_3c = df.query("loan_percent_income >= 0.4 & loan_percent_income <= 0.6")

# d) Loan amounts that are multiples of 10,000
task_3d = df[df['loan_amount'] % 10000 == 0]

# %%
task_3a
# Out:
# Empty DataFrame
# Columns: [person_age, person_education, person_gender, person_income, person_emp_exp, person_home_ownership, loan_amount, loan_intent, loan_int_rate, loan_percent_income, cb_person_cred_hist_length, credit_score, previous_loan_defaults_on_file, loan_status]
# Index: []

# %%
task_3b
# Out:
#        person_age person_education person_gender  person_income  \
# 28           23.0      High School          male        14293.0
# 31           21.0      High School          male        14858.0
# 36           21.0        Associate          male        15150.0
# 44           23.0      High School          male       361547.0
# 58           23.0         Bachelor          male       333399.0
# ...           ...              ...           ...            ...
# 26133        28.0         Bachelor          male       115901.0
# 26170        29.0         Bachelor          male       117074.0
# 26193        31.0         Bachelor          male       118242.0
# 26209        29.0      High School          male        39306.0
# 26226        29.0         Bachelor          male       119600.0
#
#        person_emp_exp person_home_ownership  loan_amount      loan_intent  \
# 28                  0                   OWN       1400.0         PERSONAL
# 31                  0                   OWN       2000.0          MEDICAL
# 36                  0                   OWN       2500.0        EDUCATION
# 44                  0                   OWN      24250.0        EDUCATION
# 58                  1                   OWN      35000.0         PERSONAL
# ...               ...                   ...          ...              ...
# 26133               6                   OWN      15000.0        EDUCATION
# 26170               3                   OWN      14600.0          MEDICAL
# 26193               3                   OWN       5100.0  HOMEIMPROVEMENT
# 26209               6                   OWN       2100.0  HOMEIMPROVEMENT
# 26226               4                   OWN       9000.0          VENTURE
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 28              9.32                 0.10                         3.0
# 31             11.12                 0.13                         3.0
# 36              7.51                 0.17                         4.0
# 44             19.41                 0.07                         2.0
# 58             11.01                 0.10                         4.0
# ...              ...                  ...                         ...
# 26133          13.47                 0.13                         6.0
# 26170          15.65                 0.12                         9.0
# 26193           6.03                 0.04                         6.0
# 26209           6.91                 0.05                         5.0
# 26226          11.89                 0.08                         6.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 28            607.0                             No          0.0
# 31            589.0                             No          1.0
# 36            600.0                             No          1.0
# 44            637.0                            Yes          0.0
# 58            609.0                             No          0.0
# ...             ...                            ...          ...
# 26133         628.0                            Yes          0.0
# 26170         658.0                            Yes          0.0
# 26193         640.0                            Yes          0.0
# 26209         662.0                            Yes          0.0
# 26226         592.0                            Yes          0.0
#
# [922 rows x 14 columns]

# %%
task_3c
# Out:
#        person_age person_education person_gender  person_income  \
# 1            22.0           Master        female        71948.0
# 3            25.0      High School        female        12438.0
# 4            23.0         Bachelor        female        79753.0
# 5            24.0           Master          male        66135.0
# 23           22.0           Master        female        79255.0
# ...           ...              ...           ...            ...
# 25038        30.0        Associate          male        28108.0
# 25041        32.0      High School        female        29697.0
# 25939        29.0        Associate        female        42250.0
# 26026        27.0           Master        female        41220.0
# 26131        30.0         Bachelor        female        28849.0
#
#        person_emp_exp person_home_ownership  loan_amount loan_intent  \
# 1                   0                  RENT      35000.0    PERSONAL
# 3                   3              MORTGAGE       5500.0     MEDICAL
# 4                   0                  RENT      35000.0     MEDICAL
# 5                   1                  RENT      35000.0     MEDICAL
# 23                  0                  RENT      34000.0   EDUCATION
# ...               ...                   ...          ...         ...
# 25038               6                  RENT      12000.0     VENTURE
# 25041              12                  RENT      12000.0     MEDICAL
# 25939               4                   OWN      20000.0     VENTURE
# 26026               6                   OWN      21250.0    PERSONAL
# 26131               6                  RENT      14000.0     VENTURE
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 1              16.02                 0.49                         3.0
# 3              12.87                 0.44                         3.0
# 4              15.23                 0.44                         2.0
# 5              14.27                 0.53                         4.0
# 23             17.58                 0.43                         4.0
# ...              ...                  ...                         ...
# 25038           7.29                 0.43                         5.0
# 25041          11.01                 0.40                         8.0
# 25939           7.29                 0.47                        10.0
# 26026           8.88                 0.52                         6.0
# 26131           7.88                 0.49                         6.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 1             561.0                             No          1.0
# 3             635.0                             No          1.0
# 4             675.0                             No          1.0
# 5             586.0                             No          1.0
# 23            691.0                             No          1.0
# ...             ...                            ...          ...
# 25038         571.0                             No          1.0
# 25041         700.0                             No          1.0
# 25939         648.0                             No          0.0
# 26026         666.0                            Yes          0.0
# 26131         614.0                             No          1.0
#
# [302 rows x 14 columns]

# %%
task_3d
# Out:
#        person_age person_education person_gender  person_income  \
# 16           23.0           Master        female       600891.0
# 37           22.0         Bachelor        female        58868.0
# 38           24.0      High School          male        78026.0
# 39           25.0         Bachelor          male        90785.0
# 40           23.0      High School        female        86811.0
# ...           ...              ...           ...            ...
# 26215        29.0        Associate          male       118788.0
# 26221        28.0      High School        female       119301.0
# 26227        33.0         Bachelor          male       119460.0
# 26247        28.0      High School          male       120995.0
# 26250        31.0         Bachelor        female        90664.0
#
#        person_emp_exp person_home_ownership  loan_amount        loan_intent  \
# 16                  5              MORTGAGE      30000.0  DEBTCONSOLIDATION
# 37                  0                  RENT      30000.0          EDUCATION
# 38                  3                  RENT      30000.0  DEBTCONSOLIDATION
# 39                  4                  RENT      30000.0    HOMEIMPROVEMENT
# 40                  0                  RENT      30000.0  DEBTCONSOLIDATION
# ...               ...                   ...          ...                ...
# 26215               7              MORTGAGE      20000.0            VENTURE
# 26221               6              MORTGAGE      20000.0            VENTURE
# 26227              11              MORTGAGE      10000.0            MEDICAL
# 26247               2              MORTGAGE      10000.0            VENTURE
# 26250               8              MORTGAGE      10000.0            MEDICAL
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 16             10.65                 0.05                         3.0
# 37             18.39                 0.51                         2.0
# 38             14.54                 0.38                         3.0
# 39             16.89                 0.33                         4.0
# 40             11.01                 0.35                         4.0
# ...              ...                  ...                         ...
# 26215           8.88                 0.17                         9.0
# 26221          14.84                 0.17                         9.0
# 26227          11.01                 0.08                         7.0
# 26247           5.42                 0.08                         8.0
# 26250          15.58                 0.11                         6.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 16            670.0                            Yes          0.0
# 37            606.0                             No          1.0
# 38            582.0                             No          1.0
# 39            649.0                             No          1.0
# 40            602.0                             No          1.0
# ...             ...                            ...          ...
# 26215         652.0                            Yes          0.0
# 26221         607.0                            Yes          0.0
# 26227         582.0                             No          0.0
# 26247         650.0                             No          0.0
# 26250         687.0                             No          1.0
#
# [3002 rows x 14 columns]
